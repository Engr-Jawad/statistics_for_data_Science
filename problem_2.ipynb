# %% [markdown]
# # Student Exam Scores

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statistics import mode

# %%
scores = [78, 85, 92, 88, 76, 95, 89, 84, 73, 91,
          87, 82, 94, 79, 81, 77, 90, 86, 83, 80,
          75, 97, 98, 72, 74, 96, 93, 99, 65, 100]
# mean
mean = np.mean(scores)
print("mean of scores : ",mean)
# Median
median = np.median(scores)
print("median of scores : ",median)
# mode
print("mode of scores : ",mode(scores))
# min value
min_value = np.min(scores)
print("minimum scores : ",min_value)
# max_value
max_value = np.max(scores)
print("max scores : ",max_value)
# range 
range = max_value - min_value
print("range : ",range)
# varience
varience = np.var(scores)
print("population varience : ", varience.round(2))
# standard deviation
std_varience = np.std(scores)
print("standard deviation of varience : ", std_varience)
# Out:
# mean of scores :  85.3
# median of scores :  85.5
# mode of scores :  78
# minimum scores :  65
# max scores :  100
# range :  35
# population varience :  81.88
# standard deviation of varience :  9.048572631452249
